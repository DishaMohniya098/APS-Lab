# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )

import matplotlib.pyplot as plt


def check_number(num):
    if num > 0:
        return "Positive"
    elif num < 0:
        return "Negative"
    else:
        return "Zero"


print(check_number(10))
print(check_number(-5))
print(check_number(0))


input_sizes = [1, 10, 100, 1000, 10000, 100000]
steps = [3 for _ in input_sizes]

plt.figure(figsize=(8, 5))
plt.plot(input_sizes, steps,)
plt.title("Constant Time Complexity O(1)", fontsize=14)
plt.xlabel("Input Size", fontsize=12)
plt.ylabel("Steps of Execution", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Positive
# Negative
# Zero

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)



plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)


import matplotlib.pyplot as plt

def count_positive_elements(arr):
    count = 0
    for num in arr:
        if num > 0:
            count += 1
    return count


example_list = [10, -5, 0, 7, -3, 2]
print("Count of positive elements:", count_positive_elements(example_list))


input_sizes = [10, 100, 1000, 5000, 10000]
steps = [size for size in input_sizes]

plt.style.use('seaborn-v0_8')
plt.figure(figsize=(8, 5))
plt.plot(input_sizes, steps, marker='o', color='green', linewidth=2)
plt.title("Linear Time Complexity O(n)", fontsize=14)
plt.xlabel("Input Size", fontsize=12)
plt.ylabel("Steps of Execution", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Count of positive elements: 3

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.

import matplotlib.pyplot as plt


def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    steps = 0
    while left <= right:
        steps += 1
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid, steps
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1, steps

sorted_list = [1, 3, 5, 7, 9, 11, 13, 15]
index, steps = binary_search(sorted_list, 11)
print(f"Element found at index {index} in {steps} steps")

import math
input_sizes = [10, 100, 1000, 5000, 10000, 50000]
steps = [math.log2(size) for size in input_sizes]

plt.figure(figsize=(8, 5))
plt.plot(input_sizes, steps, marker='o', color='red', linewidth=2)
plt.title("Logarithmic Time Complexity O(log n)", fontsize=14)
plt.xlabel("Input Size", fontsize=12)
plt.ylabel("Steps of Execution", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Element found at index 5 in 2 steps

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.

import matplotlib.pyplot as plt
import math


def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
          result.append(left[i])
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result


example_list = [38, 27, 43, 3, 9, 82, 10]
sorted_list = merge_sort(example_list)
print("Sorted List:", sorted_list)

input_sizes = [10, 100, 1000, 5000, 10000, 50000]
steps = [size * math.log2(size) for size in input_sizes]

plt.style.use('seaborn-v0_8')
plt.figure(figsize=(8, 5))
plt.plot(input_sizes, steps, marker='o', color='purple', linewidth=2)
plt.title("Log-Linear Time Complexity O(n log n)", fontsize=14)
plt.xlabel("Input Size", fontsize=12)
plt.ylabel("Steps of Execution", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example

import matplotlib.pyplot as plt

def check_pairs(arr):
    results = []
    for i in range(len(arr)):
        for j in range(len(arr)):
            if (arr[i] + arr[j]) % 2 == 0:
                results.append((arr[i], arr[j]))
    return results

example_list = [1, 2, 3, 4]
pairs = check_pairs(example_list)
print("Even-sum pairs:", pairs)


input_sizes = [10, 50, 100, 200, 500]
steps = [size**2 for size in input_sizes]

plt.style.use('seaborn-v0_8')
plt.figure(figsize=(8, 5))
plt.plot(input_sizes, steps, marker='o', color='darkblue', linewidth=2)
plt.title("Polynomial Time Complexity O(n^2)", fontsize=14)
plt.xlabel("Input Size", fontsize=12)
plt.ylabel("Steps of Execution", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Even-sum pairs: [(1, 1), (1, 3), (2, 2), (2, 4), (3, 1), (3, 3), (4, 2), (4, 4)]

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example

def power_function():
  return x ** n

  n_values = list(range(1, 101))
  time_values = [math.c^(n) if n > 0 else 0 for n in n_values]

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(c^n) Exponential Time Complexity")
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure

import matplotlib.pyplot as plt
import numpy as np


n_values = np.arange(1, 10)


linear = n_values
logarithmic = np.log2(n_values)
quadratic = n_values ** 2
exponential = 2 ** n_values

plt.figure(figsize=(10, 6))
plt.plot(n_values, linear, label='O(n)', color='blue', marker='o')
plt.plot(n_values, logarithmic, label='O(log₂n)', color='red', marker='o')
plt.plot(n_values, quadratic, label='O(n²)', color='green', marker='o')
plt.plot(n_values, exponential, label='O(2ⁿ)', color='gold', marker='o')
plt.title("Time Complexity Plot", fontsize=16)
plt.xlabel("Values of n", fontsize=12)
plt.ylabel("Time Complexity", fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)

import matplotlib.pyplot as plt
import math

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)


def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr


example_list = [38, 27, 43, 3, 9, 82, 10]

print("Quick Sort Result:", quick_sort(example_list))
print("Bubble Sort Result:", bubble_sort(example_list.copy()))
input_sizes = [10, 50, 100, 200, 500, 1000]
quick_sort_steps = [size * math.log2(size) for size in input_sizes]
bubble_sort_steps = [size**2 for size in input_sizes]

plt.figure(figsize=(8, 5))
plt.plot(input_sizes, quick_sort_steps, marker='o', color='orange', label="Quick Sort O(n log n)")
plt.plot(input_sizes, bubble_sort_steps, marker='o', color='blue', label="Bubble Sort O(n^2)")
plt.title("Quick Sort vs Bubble Sort Time Complexity", fontsize=14)
plt.xlabel("Input Size (n)", fontsize=12)
plt.ylabel("Steps of Execution", fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Quick Sort Result: [3, 9, 10, 27, 38, 43, 82]
# Bubble Sort Result: [3, 9, 10, 27, 38, 43, 82]
